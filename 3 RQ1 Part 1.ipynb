# %%
def remove_outliers(df, threshold=3, columns=None):
    """
    Remove outliers from DataFrame using Z-score method.
    
    Parameters:
    - df: Input pandas DataFrame.
    - threshold: Z-score threshold for outlier detection (default: 3).
    - columns: List of columns to apply outlier removal (default: all columns).
    
    Returns:
    - DataFrame with outliers removed.
    """
    # Select columns if specified, otherwise use all columns
    if columns is None:
        columns = df.columns
    
    # Calculate Z-scores for selected columns
    z_scores = df[columns].apply(lambda x: (x - x.mean()) / x.std())
    
    # Filter out rows with outliers
    filtered_df = df[(z_scores.abs() < threshold).all(axis=1)]
    
    return filtered_df

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from cliffs_delta import cliffs_delta

migsdf = pd.read_csv("Implementation Smell Simulation Group.csv ")
migtdf = pd.read_csv("Implementation Smell Traditional Group.csv")

migsdf = remove_outliers(migsdf,1, ['Avg'])
migtdf = remove_outliers(migtdf,1, ['Avg'])

statistic, p_value = mannwhitneyu(migsdf['Avg'], migtdf['Avg'])
plt.figure(facecolor='white')
plt.boxplot([migsdf['Avg'], migtdf['Avg']], labels=['Simulation Software', 'Traditional Software'], patch_artist=True )
plt.title("Implementation Smells")
plt.savefig('a.png')
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(migsdf['Avg'], migtdf['Avg'])


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 21664.5
# p-value: 1.488761234349431e-12
# The difference in distributions is statistically significant

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from cliffs_delta import cliffs_delta

migsdf = pd.read_csv("Implementation Smell Simulation Group.csv ")
migtdf = pd.read_csv("Implementation Smell Traditional Group.csv")

migsdf = remove_outliers(migsdf,1, ['Avg'])
migtdf = remove_outliers(migtdf,1, ['Avg'])

migtdf = migtdf.sample(n=len(migsdf), random_state=42)

statistic, p_value = mannwhitneyu(migsdf['Avg'], migtdf['Avg'])
plt.figure(facecolor='white')
plt.boxplot([migsdf['Avg'], migtdf['Avg']], labels=['Simulation Software', 'Traditional Software'], patch_artist=True,showfliers=False)
plt.title("Implementation Smells Random subspample")
plt.savefig('a.png')
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(migsdf['Avg'], migtdf['Avg'])
print(cf_delta)


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 8975.5
# p-value: 4.056182937734017e-09
# (0.4569434299164029, 'medium')
# The difference in distributions is statistically significant

# %%
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

mdgsdf = pd.read_csv("Design Smell Simulation.csv ")
mdgtdf = pd.read_csv("Design Smell Traditional.csv")

mdgsdf = remove_outliers(mdgsdf,1, ['Avg'])
mdgtdf = remove_outliers(mdgtdf,1, ['Avg'])

statistic, p_value = mannwhitneyu(mdgsdf['Avg'], mdgtdf['Avg'])

plt.boxplot([mdgsdf['Avg'], mdgtdf['Avg']], labels=['Simulation Software', 'Traditional Software'] , patch_artist=True,showfliers=False )
plt.title("Design Smells")
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(mdgsdf['Avg'], mdgtdf['Avg'])
print(cf_delta)


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 404775.0
# p-value: 1.7332133378190277e-12
# (-0.18599413187789962, 'small')
# The difference in distributions is statistically significant

# %%
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

mdgsdf = pd.read_csv("Design Smell Simulation Group.csv ")
mdgtdf = pd.read_csv("Design Smell Traditional Group.csv")

mdgsdf = remove_outliers(mdgsdf,1, ['Avg'])
mdgtdf = remove_outliers(mdgtdf,1, ['Avg'])


mdgtdf = mdgtdf.sample(n=len(mdgsdf), random_state=0)
statistic, p_value = mannwhitneyu(mdgsdf['Avg'], mdgtdf['Avg'])

plt.boxplot([mdgsdf['Avg'], mdgtdf['Avg']], labels=['Simulation Software', 'Traditional Software'] , patch_artist=True)
plt.title("Design Smells")
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(mdgsdf['Avg'], mdgtdf['Avg'])
print(cf_delta)


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 3170.0
# p-value: 0.006341555283379608
# (-0.2343919816447289, 'small')
# The difference in distributions is statistically significant

# %%
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

magsdf = pd.read_csv("Architecture Smell Simulation Group.csv")
magtdf = pd.read_csv("Architecture Smell Traditional Group.csv")

magsdf = remove_outliers(magsdf,1, ['Avg'])
magtdf = remove_outliers(magtdf,1, ['Avg'])

statistic, p_value = mannwhitneyu(magsdf['Avg'], magtdf['Avg'])

plt.boxplot([magsdf['Avg'], magtdf['Avg']], labels=['Simulation Software', 'Traditional Software'], patch_artist=True )
plt.title("Architectural Smells")
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(magsdf['Avg'], magtdf['Avg'])
print(cf_delta)


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 10839.5
# p-value: 0.6569031877901723
# (-0.030672926447574335, 'negligible')
# The difference in distributions is not statistically significant

# %%
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

magsdf = pd.read_csv("Architecture Smell Simulation Group.csv")
magtdf = pd.read_csv("Architecture Smell Traditional Group.csv")
magtdf = magtdf.sample(n=len(magsdf), random_state=0)

magsdf = remove_outliers(magsdf,1, ['Avg'])
magtdf = remove_outliers(magtdf,1, ['Avg'])

statistic, p_value = mannwhitneyu(magsdf['Avg'], magtdf['Avg'])

plt.boxplot([magsdf['Avg'], magtdf['Avg']], labels=['Simulation Software', 'Traditional Software'], patch_artist=True )
plt.title("Architectural Smells Random Subsample")
plt.show()

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(magsdf['Avg'], magtdf['Avg'])
print(cf_delta)


if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 6117.5
# p-value: 0.6917442890554245
# (0.031184155077960386, 'negligible')
# The difference in distributions is not statistically significant

# %% [markdown]
# ## Get overall comparison graph

# %%
import pandas as pd
super_mgsdf = pd.merge(magsdf, migsdf, on=['Project Name'], how='outer')
super_mgsdf["Count"] = super_mgsdf["Count_x"]+super_mgsdf["Count_y"]
super_mgsdf["LOC"] = super_mgsdf["LOC_x"].combine_first(super_mgsdf["LOC_y"])

super_mgsdf = super_mgsdf.drop(columns=['Count_x', 'Count_y', 'Avg_x', 'Avg_y', 'Unnamed: 0_x', 'Unnamed: 0_y', 'LOC_x', 'LOC_y'])


super_mgsdf = pd.merge(super_mgsdf, mdgsdf, on=['Project Name'], how='outer')
super_mgsdf = super_mgsdf.fillna(0)
super_mgsdf["Count"] = super_mgsdf["Count_x"]+super_mgsdf["Count_y"]


super_mgsdf["LOC"] = super_mgsdf["LOC_x"].combine_first(super_mgsdf["LOC_y"])


super_mgsdf = super_mgsdf.drop(columns=['Count_x', 'Count_y', 'Avg', 'Unnamed: 0', 'LOC_x', 'LOC_y'])



super_mgsdf['Avg'] = super_mgsdf['Count'] / super_mgsdf['LOC']
super_mgsdf = super_mgsdf.fillna(0)

super_mgsdf
# Out:
#                            Project Name   Count      LOC       Avg
# 0                                 ARGON   174.0   2481.0  0.070133
# 1               AutoInteraction-Library    76.0   3519.0  0.021597
# 2          Baseform-Epanet-Java-Library  1487.0  14447.0  0.102928
# 3    Black-Scholes-Option-Pricing-Model    46.0   2711.0  0.016968
# 4                     BoomChess-Android    45.0   3470.0  0.012968
# ..                                  ...     ...      ...       ...
# 121               supermarket-simulator     0.0    736.0  0.000000
# 122               texas-holdem-poker-ai    24.0   2122.0  0.011310
# 123                          RADDOSE-3D   205.0      0.0       inf
# 124                            end-game    89.0      0.0       inf
# 125                            imp_city   155.0      0.0       inf
#
# [126 rows x 4 columns]

# %%
print(len(super_mgsdf[super_mgsdf['Count']==0]))
print(len(super_mgsdf[super_mgsdf['LOC']==0]))
# Out:
# 9
# 3

# %%
super_mgtdf = pd.merge(magtdf, migtdf, on=['Project Name'], how='outer')
super_mgtdf = super_mgtdf.fillna(0)
super_mgtdf["Count"] = super_mgtdf["Count_x"]+super_mgtdf["Count_y"]
super_mgtdf["LOC"] = super_mgtdf.apply(lambda row: row['LOC_x'] if row['LOC_x'] != 0 else row['LOC_y'], axis=1)


print(len(super_mgtdf[super_mgtdf['LOC']==0]))

super_mgtdf = super_mgtdf.drop(columns=['Count_x', 'Count_y', 'Avg_x', 'Avg_y', 'Unnamed: 0_x', 'Unnamed: 0_y', 'LOC_x', 'LOC_y'])

super_mgtdf = pd.merge(super_mgtdf, mdgtdf, on=['Project Name'], how='outer')
super_mgtdf = super_mgtdf.fillna(0)
super_mgtdf["Count"] = super_mgtdf["Count_x"]+super_mgtdf["Count_y"]
super_mgtdf["LOC"] =  super_mgtdf.apply(lambda row: row['LOC_x'] if row['LOC_x'] != 0 else row['LOC_y'], axis=1)


print(len(super_mgtdf[super_mgtdf['LOC']==0]))

super_mgtdf = super_mgtdf.drop(columns=['Count_x', 'Count_y', 'Avg', 'Unnamed: 0', 'LOC_x', 'LOC_y'])

super_mgtdf['Avg'] = super_mgtdf['Count'] / super_mgtdf['LOC']


super_mgtdf
# Out:
# 0
# 0
#                        Project Name  Count      LOC       Avg
# 0                           xyz-hub  282.0  48891.0  0.005768
# 1                         jentunnel  226.0   5995.0  0.037698
# 2            TASK-Management-System    4.0   1600.0  0.002500
# 3              gwt-polymer-elements    5.0   1365.0  0.003663
# 4                  SecureWebSockets  194.0   1774.0  0.109357
# ..                              ...    ...      ...       ...
# 206  felix-search-webconsole-plugin   55.0   2733.0  0.020124
# 207                      pdfjuggler   10.0   1103.0  0.009066
# 208                          regain  263.0  27466.0  0.009575
# 209             desktop-spring-boot    8.0    301.0  0.026578
# 210                      bambu-farm  142.0   7727.0  0.018377
#
# [211 rows x 4 columns]

# %%
print(len(super_mgtdf[super_mgtdf['Count']==0]))
print(len(super_mgtdf[super_mgtdf['LOC']==0]))
# Out:
# 0
# 0

# %%
# super_mgsdf = remove_outliers(super_mgsdf,1, ['Count'])
# super_mgtdf = remove_outliers(super_mgtdf,1, ['Count'])

# %%
super_mgsdf
# Out:
#                            Project Name   Count      LOC       Avg
# 0                                 ARGON   174.0   2481.0  0.070133
# 1               AutoInteraction-Library    76.0   3519.0  0.021597
# 2          Baseform-Epanet-Java-Library  1487.0  14447.0  0.102928
# 3    Black-Scholes-Option-Pricing-Model    46.0   2711.0  0.016968
# 4                     BoomChess-Android    45.0   3470.0  0.012968
# ..                                  ...     ...      ...       ...
# 121               supermarket-simulator     0.0    736.0  0.000000
# 122               texas-holdem-poker-ai    24.0   2122.0  0.011310
# 123                          RADDOSE-3D   205.0      0.0       inf
# 124                            end-game    89.0      0.0       inf
# 125                            imp_city   155.0      0.0       inf
#
# [126 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

statistic, p_value = mannwhitneyu(super_mgsdf['Avg'], super_mgtdf['Avg'])

fig, (ax1) = plt.subplots(1, 1, figsize=(6, 5))

box = ax1.boxplot([super_mgsdf['Avg'], super_mgtdf['Avg']], labels=['Simulation Software', 'Traditional Software'], patch_artist=True,showfliers=False )
# plt.title("All Smells")
# plt.ylim(-0.05, 0.3)


colors = ['white', 'white']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)


print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

cf_delta = cliffs_delta(super_mgsdf['Avg'], super_mgtdf['Avg'])
print(cf_delta)


# ax1.set_title('Comparison of Software Smells Per Line of Code')
plt.tight_layout()
plt.savefig('comparison_box_plot.png')
plt.show()

if p_value < 0.05:
    print("The difference in distributions is statistically significant")
else:
    print("The difference in distributions is not statistically significant")
# Out:
# Mann-Whitney U statistic: 19202.0
# p-value: 8.616583915355833e-12
# (0.44451967200782366, 'medium')
# The difference in distributions is statistically significant

# %%
bloaters = ['Long Parameter List', 'Long Statement','Long Method', 'Long Identifier']
oop_abusers = ['Abstract Function Call From Constructor', 'Broken Hierarchy','Imperative Abstraction', 'Unutilized Abstraction','Wide Hierarchy','Rebellious Hierarchy','Missing Hierarchy', 'Cyclic Hierarchy','Multipath Hierarchy','Multifaceted Abstraction']
c_preventers = ['Cyclic Dependency','Unstable Dependency']
dispensables = ['Empty catch clause', 'Magic Number','Unexploited Encapsulation']
couplers = ['Scattered Functionality', 'Missing Hierarchy', 'Deficient Encapsulation']

# %%
magsdf
# Out:
#      Unnamed: 0                        Project Name    LOC  Count       Avg
# 0             0                               ARGON   2481      1  0.000403
# 1             1             AutoInteraction-Library   3519      1  0.000284
# 2             2        Baseform-Epanet-Java-Library  14447     62  0.004292
# 3             3  Black-Scholes-Option-Pricing-Model   2711      1  0.000369
# 4             4                   BoomChess-Android   3470     22  0.006340
# ..          ...                                 ...    ...    ...       ...
# 122         122                     trucksimulation   2425     19  0.007835
# 123         123                  universe-maker-app   1374     10  0.007278
# 124         124                              varsim   9302     37  0.003978
# 125         125                            vatprism  16084     33  0.002052
# 126         126                           weblabora   8477      5  0.000590
#
# [105 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize =(6, 5))
box1 = ax.boxplot([super_mgsdf['Avg']], labels=["Simulation\nSystems"], positions=[1], patch_artist=True,  boxprops=dict(facecolor="gray", color="black"), showfliers=False)
box1 = ax.boxplot([super_mgtdf['Avg']], labels=["Traditional\nSystems"], positions=[2], patch_artist=True,  boxprops=dict(facecolor="white", color="black"), showfliers=False)
# plt.ylim(0,0.3)

ax.tick_params(axis='both', which='major', labelsize=8)
ax.tick_params(axis='both', which='minor', labelsize=8)

# # Create a custom legend
# legend_labels = ['Simulation Software', 'Traditional Software']
# legend_colors = ['white', 'gray']
# custom_legend = [plt.Line2D([0], [0], marker='s', color='black', markerfacecolor=color, markersize=10, label=label)
#                  for label, color in zip(legend_labels, legend_colors)]

# Add the legend to the figure
# fig.legend(handles=custom_legend, loc='lower left', bbox_to_anchor=(0.56, 0.72), title="Legend")

plt.xticks(fontsize=14)
plt.ylabel('Code smell per line of code', size=14)

# plt.title('')

plt.savefig('comparison_box_plot.png')

# %%
super_mgsdf
# Out:
#                            Project Name   Count      LOC       Avg
# 0                                 ARGON   174.0   2481.0  0.070133
# 1               AutoInteraction-Library    76.0   3519.0  0.021597
# 2          Baseform-Epanet-Java-Library  1487.0  14447.0  0.102928
# 3    Black-Scholes-Option-Pricing-Model    46.0   2711.0  0.016968
# 4                     BoomChess-Android    45.0   3470.0  0.012968
# ..                                  ...     ...      ...       ...
# 121               supermarket-simulator     0.0    736.0  0.000000
# 122               texas-holdem-poker-ai    24.0   2122.0  0.011310
# 123                          RADDOSE-3D   205.0      0.0       inf
# 124                            end-game    89.0      0.0       inf
# 125                            imp_city   155.0      0.0       inf
#
# [126 rows x 4 columns]

# %% [markdown]
# ## Break Down Overall comparison by smell type

# %%
fig, ax = plt.subplots(figsize =(6, 5))
box1 = ax.boxplot([migsdf['Avg'], mdgsdf['Avg'], magsdf['Avg']], labels=["Implementation \n Smell", "Design\n Smell", "Architecture \n Smell"], positions=[0, 1, 2], patch_artist=True,  boxprops=dict(facecolor="gray", color="black"), showfliers=False)
box2 = ax.boxplot([migtdf['Avg'], mdgtdf['Avg'], magtdf['Avg']],  labels=["Implementation \n Smell", "Design\n Smell", "Architecture \n Smell"],positions=[4, 5, 6], patch_artist=True, showfliers=False, boxprops=dict(facecolor="white", color="black"))
# plt.ylim(0,0.3)

ax.tick_params(axis='both', which='major', labelsize=8)
ax.tick_params(axis='both', which='minor', labelsize=8)

# Create a custom legend
legend_labels = ['Simulation Systems', 'Traditional Systems', ]
legend_colors = ['gray', 'white']
custom_legend = [plt.Line2D([0], [0], marker='s', color='black', markerfacecolor=color, markersize=10, label=label)
                 for label, color in zip(legend_labels, legend_colors)]

# Add the legend to the figure
fig.legend(handles=custom_legend, loc='lower left', bbox_to_anchor=(0.56, 0.72), title="Legend")

plt.xticks(fontsize=8.3)
plt.ylabel('Code smell per line of code', size=14)
# plt.title('')

plt.savefig('Comparison.png')

# %%
fig, ax = plt.subplots(figsize =(6, 5))
box1 = ax.boxplot([migsdf['Avg'], mdgsdf['Avg'], magsdf['Avg']], labels=["Implementation \n Smell", "Design\n Smell", "Architecture \n Smell"], positions=[1, 2, 3], patch_artist=True,  boxprops=dict(facecolor="white", color="black"), showfliers=False)
box2 = ax.boxplot([migtdf['Avg'], mdgtdf['Avg'], magtdf['Avg']],  labels=["Implementation \n Smell", "Design\n Smell", "Architecture \n Smell"],positions=[5, 6, 7], patch_artist=True, showfliers=False, boxprops=dict(facecolor="gray", color="black"))
# plt.ylim(0,0.3)

ax.tick_params(axis='both', which='major', labelsize=8)
ax.tick_params(axis='both', which='minor', labelsize=8)

# Create a custom legend
legend_labels = ['Simulation Software', 'Traditional Software']
legend_colors = ['white', 'gray']
custom_legend = [plt.Line2D([0], [0], marker='s', color='black', markerfacecolor=color, markersize=10, label=label)
                 for label, color in zip(legend_labels, legend_colors)]

# Add the legend to the figure
fig.legend(handles=custom_legend, loc='lower left', bbox_to_anchor=(0.56, 0.72), title="Legend")
plt.ylabel('Code smell per line of code')
# plt.ylabel('', fontsize=1)
# plt.title('')

plt.savefig('Comparison.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ["Implementation Smell", "Design Smell", "Architecture Smell"]
simulation_data = [migsdf['Count'].sum(), mdgsdf['Count'].sum(), magsdf['Count'].sum()]
traditional_data = [migtdf['Count'].sum(), mdgtdf['Count'].sum(), magtdf['Count'].sum()]

fig, ax = plt.subplots(figsize=(15, 8))

bar_width = 0.35
bar1 = ax.bar(np.arange(len(categories)), simulation_data, bar_width, label='Simulation Software', color='red')
bar2 = ax.bar(np.arange(len(categories)) + bar_width, traditional_data, bar_width, label='Traditional Software', color='blue')

ax.set_xlabel('Smell Type')
ax.set_ylabel('Total Code Smells')
ax.set_title('Comparison of Software Smells between Simulation and Traditional Software')
ax.set_xticks(np.arange(len(categories)) + bar_width / 2)
ax.set_xticklabels(categories)
ax.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ["Implementation\nSmell", "Design\nSmell", "Architecture\nSmell"]
simulation_data = [migsdf['Count'].sum()/migsdf['LOC'].sum(), mdgsdf['Count'].sum()/mdgsdf['LOC'].sum(), magsdf['Count'].sum()/magsdf['LOC'].sum()]
traditional_data = [migtdf['Count'].sum()/migtdf['LOC'].sum(), mdgtdf['Count'].sum()/mdgtdf['LOC'].sum(), magtdf['Count'].sum()/magtdf['LOC'].sum()]

fig, ax = plt.subplots(figsize=(5, 4))

bar_width = 0.35
bar1 = ax.bar(np.arange(len(categories)), simulation_data, bar_width, label='Simulation Software', color='gray', edgecolor='black', hatch='/')
bar2 = ax.bar(np.arange(len(categories)) + bar_width, traditional_data, bar_width, label='Traditional Software',color='white', edgecolor='black', hatch='\\')

# ax.set_xlabel('Smell Type')
ax.set_ylabel('Code smell per line of code', fontsize=14)
# ax.set_title('Comparison of Software Smells between Simulation and Traditional Software')
ax.set_xticks(np.arange(len(categories)) + bar_width / 2)
ax.set_xticklabels(categories, fontsize=12)
ax.legend()

plt.savefig('all_smells_bar.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ["Implementation\nSmell", "Design\nSmell", "Architecture\nSmell"]
simulation_data = [migsdf['Count'].sum()/migsdf['LOC'].sum(), mdgsdf['Count'].sum()/mdgsdf['LOC'].sum(), magsdf['Count'].sum()/magsdf['LOC'].sum()]
traditional_data = [migtdf['Count'].sum()/migtdf['LOC'].sum(), mdgtdf['Count'].sum()/mdgtdf['LOC'].sum(), magtdf['Count'].sum()/magtdf['LOC'].sum()]

fig, ax = plt.subplots(figsize=(5, 4))

bar_width = 0.35
bar1 = ax.bar(np.arange(len(categories)), simulation_data, bar_width, label='Simulation Software', color='gray', edgecolor='black', hatch='/')
bar2 = ax.bar(np.arange(len(categories)) + bar_width, traditional_data, bar_width, label='Traditional Software',color='white', edgecolor='black', hatch='\\')

# ax.set_xlabel('Smell Type')
ax.set_ylabel('Code smell per line of code', fontsize=14)
# ax.set_title('Comparison of Software Smells between Simulation and Traditional Software')
ax.set_xticks(np.arange(len(categories)) + bar_width / 2)
ax.set_xticklabels(categories, fontsize=12)
ax.legend()

plt.savefig('all_smells_bar.png')

# %%
import matplotlib.pyplot as plt

# Data for the bars
bar_names = ['Simulation\nSoftware', 'Traditonal\nSoftware']
bar_values = [super_mgsdf['Count'].sum()/super_mgsdf['LOC'].sum(), super_mgtdf['Count'].sum()/super_mgtdf['LOC'].sum()]

colors = ['gray', 'white'] 
edge_colors = ['black', 'black'] 
hatches = ['/', '\\'] 

# Creating the bar chart with specified colors and hatches
bars = plt.bar(bar_names, bar_values, color=colors,edgecolor=edge_colors)

# Applying hatches to the bars
for bar, hatch in zip(bars, hatches):
    bar.set_hatch(hatch)

# Adding labels and title
plt.ylabel('Code smell per line of code', fontsize=14)
plt.xticks(fontsize=14)
# plt.xlabel('Bars')
# plt.ylabel('Values')
# plt.title('Bar Chart with Two Bars')
plt.savefig('comparison_bar_plot.png')
# Displaying the chart
plt.show()

# %%
super_mgtdf
# Out:
#                        Project Name  Count      LOC       Avg
# 0                           xyz-hub  282.0  48891.0  0.005768
# 1                         jentunnel  226.0   5995.0  0.037698
# 2            TASK-Management-System    4.0   1600.0  0.002500
# 3              gwt-polymer-elements    5.0   1365.0  0.003663
# 4                  SecureWebSockets  194.0   1774.0  0.109357
# ..                              ...    ...      ...       ...
# 206  felix-search-webconsole-plugin   55.0   2733.0  0.020124
# 207                      pdfjuggler   10.0   1103.0  0.009066
# 208                          regain  263.0  27466.0  0.009575
# 209             desktop-spring-boot    8.0    301.0  0.026578
# 210                      bambu-farm  142.0   7727.0  0.018377
#
# [211 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example DataFrames
data1 = [super_mgsdf['Avg']]
data2 = [super_mgtdf['Avg']]

# Combine the data into a list of lists for the box plot
data = [data1, data2]

# Bar Plot
fig1, ax1 = plt.subplots(figsize=(10, 6))
bar_width = 0.35
indices = np.array([1, 2])  # Adjust the indices based on the number of bars/groups

ax1.bar(data1, bar_width, label='Simulation Software', color='gray', edgecolor='black',)
ax1.bar(data2, bar_width, label='Traditional Software', color='white', edgecolor='black', hatch='\\')

ax1.set_xlabel('Software Type')
ax1.set_ylabel('Code smell per line of code')
ax1.set_title('Comparison of Software Smells (Bar Plot)')
ax1.set_xticks(indices + bar_width / 2)
ax1.set_xticklabels(['Category 1', 'Category 2'])  # Provide labels for each bar/group
ax1.legend()

# Save the bar plot
plt.savefig('comparison_bar_plot_bw.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 16
#      13 bar_width = 0.35
#      14 indices = np.array([1, 2])  # Adjust the indices based on the number of bars/groups
# ---> 16 ax1.bar(data1, bar_width, label='Simulation Software', color='gray', edgecolor='black',)
#      17 ax1.bar(data2, bar_width, label='Traditional Software', color='white', edgecolor='black', hatch='\\')
#      19 ax1.set_xlabel('Software Type')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
# ...
